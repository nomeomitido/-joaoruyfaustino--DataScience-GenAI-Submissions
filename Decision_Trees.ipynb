# %% [markdown]
# <a href="https://colab.research.google.com/github/nomeomitido/-joaoruyfaustino--DataScience-GenAI-Submissions/blob/main/Decision_Trees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1xqQczl0FG-qtNA2_WQYuWePW9oU8irqJ)

# %% [markdown]
# # 4.01 Decision Trees
#
# Following up on our logistic regression example, we will also run an equivalent using _decision trees_.
#
# We'll begin using the inbuilt dataset from scikit-learn we used previously. The dataset is for predicting the presence of breast cancer or not. You can get more details here: [https://scikit-learn.org/1.5/datasets/toy_dataset.html](https://scikit-learn.org/1.5/datasets/toy_dataset.html). The code is the same as in the previous example.

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import load_breast_cancer

# import the data
data = load_breast_cancer()

# create a DataFrame of features
x_values = pd.DataFrame(data.data, columns=data.feature_names)

from sklearn.preprocessing import MinMaxScaler

# create a MinMaxScaler object
scaler = MinMaxScaler()

# fit and transform the data
normal_data = scaler.fit_transform(x_values)

# recreate x_values using the scaled data and original feature names
x_values = pd.DataFrame(normal_data, columns=data.feature_names)

# create y value
y_value = pd.DataFrame(data.target, columns=['class'])
y_value = np.ravel(y_value)

# %% [markdown]
# ## Train-Test split
# As before, our next step will be to split the data:

# %%
# split data into training and test
from sklearn.model_selection  import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x_values, y_value, test_size = 0.2, random_state=1984, stratify=y_value)

# print the shapes to check everything is OK
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (455, 30)
# (114, 30)
# (455,)
# (114,)

# %% [markdown]
# Our code is basically the same as before except with an extra parameter ("stratify=y_value"). This part means we make sure there is a propotionate number of each class in our training data. We want to avoid having minimal examples of one of the classes to learn from (as the split is otherwise fully random).
#
# We can confirm this has worked by looking at the size of our different datasets:
#
#
# *   `X_train` (the $x$ values we use for training) is 455 rows and 30 columns;
# *   `X_test` (the $x$ values we use for testing) is 114 rows and 30 columns;
# *   `Y_train` (the $Y$ values we use for training) is 455 rows and a single column;
# *   `Y_test` (the $Y$ values we use for testing) is 114 rows and a single columns. All seems to be correct!

# %% [markdown]
# ## Decision Trees
# We'll begin with a standard decision tree model WITHOUT adjusting for any hyperparameters. We first need to specify the model:

# %%
from sklearn.tree import DecisionTreeClassifier as DTC

# create the model
DTC_algo = DTC()
DTC_algo
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# As before, this is the unfitted/untrained algorithm. Let's make a model:

# %%
DTC_model = DTC_algo.fit(X_train, Y_train)
DTC_model
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# But how does it perform? I'll give you a metric for free, but you will then have to create some more:

# %%
from sklearn.metrics import accuracy_score

# predict the test data
predict = DTC_model.predict(X_test)

# separate the first five predictions and the first five real values in Y_test
for i in range(5):
  print(f'Predicted: {round(predict[i],2)}')
  print(f'Real: {Y_test[i]}')
  print("\n")

print("\n")

print(f'Accuracy: {round(accuracy_score(Y_test, predict),2)}')
# Out:
# Predicted: 0
# Real: 0
#
#
# Predicted: 0
# Real: 0
#
#
# Predicted: 0
# Real: 0
#
#
# Predicted: 0
# Real: 0
#
#
# Predicted: 1
# Real: 1
#
#
#
#
# Accuracy: 0.96

# %% [markdown]
# We have strong performance ... 90% accuracy. However, not as good as Logistic Regression. Let's look at the confusion matrix:

# %%
from sklearn.metrics import ConfusionMatrixDisplay as CM

# create a confusion matrix
CM.from_predictions(Y_test, predict)

# %% [markdown]
# We can also extract the precision, recall and F1 score:

# %%
from sklearn.metrics import precision_recall_fscore_support

# Calculate precision, recall, and F1-score
precision, recall, f1_score, _ = precision_recall_fscore_support(Y_test, predict, average='micro')

print(f"Micro-averaged Precision: {round(precision, 2)}")
print(f"Micro-averaged Recall: {round(recall, 2)}")
print(f"Micro-averaged F1-score: {round(f1_score, 2)}")
print("\n")

precision, recall, f1_score, _ = precision_recall_fscore_support(Y_test, predict, average='macro')

print(f"Macro-averaged Precision: {round(precision, 2)}")
print(f"Macro-averaged Recall: {round(recall, 2)}")
print(f"Macro-averaged F1-score: {round(f1_score, 2)}")
# Out:
# Micro-averaged Precision: 0.96
# Micro-averaged Recall: 0.96
# Micro-averaged F1-score: 0.96
#
#
# Macro-averaged Precision: 0.95
# Macro-averaged Recall: 0.96
# Macro-averaged F1-score: 0.95

# %% [markdown]
# We can also see our tree:

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
plot_tree(DTC_model, filled=True, feature_names=X_train.columns)
plt.show()

# %% [markdown]
# We can see it has built a fairly large tree ... maybe it has overfit? Perhaps regularisation will help ...
#
# We can search our hyperparameters and see what would be best:

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, randint

# this is the list of parameters we will tune. Some are fixed values some are distributions
tuned_parameters = {
    'criterion': ['gini', 'entropy'],
    'max_depth': randint(3, 9),  # Draw from a uniform distribution between 3 and 15
    'min_samples_split': randint(3, 9),  # Draw from a uniform distribution between 2 and 10
    'max_features': ['sqrt', 'log2', None]
}

# we will tune against f1_macro (to find the best choice)
score = 'f1_macro' # arbitrary choice

print(f"Tuning hyperparameters for {score}")
print("\n")

# do the search using 5 folds/chunks
clf = RandomizedSearchCV(DTC(), tuned_parameters, cv=5, random_state=1984,
                         scoring= score, n_iter=20, refit=True)

# pass the data to fit/train
clf.fit(X_train, Y_train)

print("Best parameters set found on the training set:")
print(clf.best_params_)
# Out:
# Tuning hyperparameters for f1_macro
#
#
# Best parameters set found on the training set:
# {'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_split': 4}

# %% [markdown]
# Now we can train the model again, but using these hyperparameters:

# %%
DTC_algo = DTC(**clf.best_params_) # get the best parameters from grid search
DTC_model = DTC_algo.fit(X_train, Y_train)

# %% [markdown]
# And now we can predict again:

# %%
# predict the test data
predict = DTC_model.predict(X_test)

# separate the first five predictions and the first five real values in Y_test
for i in range(5):
  print(f'Predicted: {round(predict[i],2)}')
  print(f'Real: {Y_test[i]}')
  print("\n")

print("\n")

print(f'Accuracy: {round(accuracy_score(Y_test, predict),2)}')
# Out:
# Predicted: 0
# Real: 0
#
#
# Predicted: 0
# Real: 0
#
#
# Predicted: 0
# Real: 0
#
#
# Predicted: 0
# Real: 0
#
#
# Predicted: 1
# Real: 1
#
#
#
#
# Accuracy: 0.95

# %% [markdown]
# Accuracy is better. However, we tuned for F1 macro ... maybe this will be better too:

# %%
# create a confusion matrix
CM.from_predictions(Y_test, predict)

# Calculate precision, recall, and F1-score
precision, recall, f1_score, _ = precision_recall_fscore_support(Y_test, predict, average='micro')

print(f"Micro-averaged Precision: {round(precision, 2)}")
print(f"Micro-averaged Recall: {round(recall, 2)}")
print(f"Micro-averaged F1-score: {round(f1_score, 2)}")
print("\n")

precision, recall, f1_score, _ = precision_recall_fscore_support(Y_test, predict, average='macro')

print(f"Macro-averaged Precision: {round(precision, 2)}")
print(f"Macro-averaged Recall: {round(recall, 2)}")
print(f"Macro-averaged F1-score: {round(f1_score, 2)}")
print("\n")
# Out:
# Micro-averaged Precision: 0.95
# Micro-averaged Recall: 0.95
# Micro-averaged F1-score: 0.95
#
#
# Macro-averaged Precision: 0.94
# Macro-averaged Recall: 0.95
# Macro-averaged F1-score: 0.94

# %% [markdown]
# F1 score is 3 points higher! Let's also check the tree:

# %%
plt.figure(figsize=(15, 10))
plot_tree(DTC_model, filled=True, feature_names=X_train.columns)
plt.show()

# %% [markdown]
# A much smaller tree so likely to be less prone to overfitting!

# %% [markdown]
# ### TASK
# Given that this is a medical domain, possibly a better metric to optimise against would be _recall_. Reoptimise the model according to _macro recall_ and evaluate the results.

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import load_breast_cancer

# import the data
data = load_breast_cancer()

# create a DataFrame of features
x_values = pd.DataFrame(data.data, columns=data.feature_names)

from sklearn.preprocessing import MinMaxScaler

# create a MinMaxScaler object
scaler = MinMaxScaler()

# fit and transform the data
normal_data = scaler.fit_transform(x_values)

# recreate x_values using the scaled data and original feature names
x_values = pd.DataFrame(normal_data, columns=data.feature_names)

# create y value
y_value = pd.DataFrame(data.target, columns=['class'])
y_value = np.ravel(y_value)

# %%
# split data into training and test
from sklearn.model_selection  import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x_values, y_value, test_size = 0.2, random_state=1984, stratify=y_value)

# print the shapes to check everything is OK
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (455, 30)
# (114, 30)
# (455,)
# (114,)

# %%
from sklearn.tree import DecisionTreeClassifier as DTC

# create the model
DTC_algo = DTC()
DTC_algo
# Out:
# DecisionTreeClassifier()

# %%
DTC_model = DTC_algo.fit(X_train, Y_train)
DTC_model
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Task
# Optimize the Decision Tree model for 'recall_macro' using `RandomizedSearchCV`, then train a new model with the best parameters found. Finally, predict on the test data, and evaluate the model's performance by printing the accuracy, precision, recall, and F1-score (micro and macro-averaged). Display the confusion matrix and visualize the new decision tree.

# %% [markdown]
# ## Optimize for Macro Recall
#
# ### Subtask:
# Modify the hyperparameter tuning to optimize the Decision Tree model for 'recall_macro' using `RandomizedSearchCV`.

# %% [markdown]
# **Reasoning**:
# I need to re-initialize and run RandomizedSearchCV, but this time setting the scoring parameter to 'recall_macro' as requested by the subtask. This will identify the best hyperparameters for macro recall.

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, randint

# this is the list of parameters we will tune. Some are fixed values some are distributions
tuned_parameters = {
    'criterion': ['gini', 'entropy'],
    'max_depth': randint(3, 9),  # Draw from a uniform distribution between 3 and 15
    'min_samples_split': randint(3, 9),  # Draw from a uniform distribution between 2 and 10
    'max_features': ['sqrt', 'log2', None]
}

# we will tune against recall_macro
score = 'recall_macro' # new choice

print(f"Tuning hyperparameters for {score}")
print("\n")

# do the search using 5 folds/chunks
clf_recall = RandomizedSearchCV(DTC(), tuned_parameters, cv=5, random_state=1984,
                         scoring= score, n_iter=20, refit=True)

# pass the data to fit/train
clf_recall.fit(X_train, Y_train)

print("Best parameters set found on the training set:")
print(clf_recall.best_params_)
# Out:
# Tuning hyperparameters for recall_macro
#
#
# Best parameters set found on the training set:
# {'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 8}

# %% [markdown]
# **Reasoning**:
# The hyperparameter tuning for 'recall_macro' has been completed. Now I will train a new Decision Tree model using the `best_params_` found by `RandomizedSearchCV`.

# %%
DTC_algo_recall_tuned = DTC(**clf_recall.best_params_) # get the best parameters from randomized search
DTC_model_recall_tuned = DTC_algo_recall_tuned.fit(X_train, Y_train)
print("Model trained with best parameters for macro recall.")
# Out:
# Model trained with best parameters for macro recall.

# %% [markdown]
# **Reasoning**:
# Now that the model is trained with the best parameters for macro recall, I need to predict on the test data (`X_test`) to evaluate its performance.

# %%
predict_recall_tuned = DTC_model_recall_tuned.predict(X_test)
print("Predictions made on the test data.")
# Out:
# Predictions made on the test data.

# %% [markdown]
# **Reasoning**:
# Now I need to evaluate the performance of the newly trained model by calculating its accuracy score on the test data.

# %%
from sklearn.metrics import accuracy_score

print(f'Accuracy (recall-tuned model): {round(accuracy_score(Y_test, predict_recall_tuned),2)}')
# Out:
# Accuracy (recall-tuned model): 0.92

# %% [markdown]
# **Reasoning**:
# Now I will evaluate the performance of the recall-tuned model by calculating the micro and macro-averaged precision, recall, and F1-score, as requested by the task. This will provide a comprehensive view of the model's performance.

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import ConfusionMatrixDisplay as CM
import matplotlib.pyplot as plt

# Calculate and print micro-averaged precision, recall, and F1-score
precision_micro, recall_micro, f1_score_micro, _ = precision_recall_fscore_support(Y_test, predict_recall_tuned, average='micro')
print(f"Micro-averaged Precision (recall-tuned model): {round(precision_micro, 2)}")
print(f"Micro-averaged Recall (recall-tuned model): {round(recall_micro, 2)}")
print(f"Micro-averaged F1-score (recall-tuned model): {round(f1_score_micro, 2)}")
print("\n")

# Calculate and print macro-averaged precision, recall, and F1-score
precision_macro, recall_macro, f1_score_macro, _ = precision_recall_fscore_support(Y_test, predict_recall_tuned, average='macro')
print(f"Macro-averaged Precision (recall-tuned model): {round(precision_macro, 2)}")
print(f"Macro-averaged Recall (recall-tuned model): {round(recall_macro, 2)}")
print(f"Macro-averaged F1-score (recall-tuned model): {round(f1_score_macro, 2)}")
print("\n")

# Create and display a confusion matrix
CM.from_predictions(Y_test, predict_recall_tuned)
plt.show()
# Out:
# Micro-averaged Precision (recall-tuned model): 0.92
# Micro-averaged Recall (recall-tuned model): 0.92
# Micro-averaged F1-score (recall-tuned model): 0.92
#
#
# Macro-averaged Precision (recall-tuned model): 0.91
# Macro-averaged Recall (recall-tuned model): 0.92
# Macro-averaged F1-score (recall-tuned model): 0.92

# %% [markdown]
# **Reasoning**:
# The subtask requires visualizing the new decision tree after optimizing for recall. I will use `plot_tree` to display the structure of `DTC_model_recall_tuned`.

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
plot_tree(DTC_model_recall_tuned, filled=True, feature_names=X_train.columns)
plt.title("Decision Tree Tuned for Macro Recall")
plt.show()

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Summarize the results of optimizing for macro recall, including the updated metrics, confusion matrix, and the characteristics of the new decision tree.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The results of optimizing for macro recall show that the best hyperparameters found by `RandomizedSearchCV` were `{'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 8}`. The updated model achieved an accuracy of 0.92. The micro-averaged precision, recall, and F1-score were all 0.92, while the macro-averaged precision was 0.91, and both macro-averaged recall and F1-score were 0.92. A confusion matrix was displayed, and the new decision tree, characterized by these parameters (e.g., a shallow `max_depth` of 3), was visualized.
#
# ### Data Analysis Key Findings
# *   The Decision Tree model was successfully optimized for 'recall\_macro' using `RandomizedSearchCV`.
# *   The best hyperparameters identified for optimizing macro recall were: `{'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 8}`.
# *   The re-trained model achieved an accuracy of 0.92 on the test set.
# *   The micro-averaged metrics (precision, recall, F1-score) for the recall-tuned model were all 0.92.
# *   The macro-averaged metrics for the recall-tuned model were: precision of 0.91, recall of 0.92, and F1-score of 0.92.
# *   A confusion matrix was generated to visualize classification performance, and the structure of the new decision tree was displayed.
#
# ### Insights or Next Steps
# *   The optimization for macro recall yielded a model with strong overall performance, particularly in macro-averaged recall (0.92), indicating good performance across all classes. This suggests the model is well-balanced for this specific objective.
# *   Further analysis of the confusion matrix could pinpoint specific classes where misclassifications still occur, which might inform future feature engineering or more targeted model improvements.
