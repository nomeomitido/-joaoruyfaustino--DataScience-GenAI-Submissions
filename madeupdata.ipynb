# %% [markdown]
# <a href="https://colab.research.google.com/github/nomeomitido/-joaoruyfaustino--DataScience-GenAI-Submissions/blob/main/madeupdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

infrastructure = {'proj1':{'date_start':'19/01/2020', 'type':'bridge', 'completed': 'yes'},
                  'proj2':{'date_start':'05/03/2022', 'type':'subway_line', 'completed': 'no'},
                  'proj3':{'date_start':'08/08/2023', 'type':'road', 'completed': 'no'},
                  'proj4':{'date_start':'17/02/2024', 'type':'grid_expansion', 'completed': 'no'}
}

infrastructure_df= pd.DataFrame(infrastructure)
infrastructure_df
# Out:
#                  proj1        proj2       proj3           proj4
# date_start  19/01/2020   05/03/2022  08/08/2023      17/02/2024
# type            bridge  subway_line        road  grid_expansion
# completed          yes           no          no              no
